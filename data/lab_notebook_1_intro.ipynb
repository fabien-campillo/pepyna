# %% [markdown]
# # Introduction

# %% [markdown]
# ## Websites
#
# - [Spikes and Bursts](https://spikesandbursts.wordpress.com) by David. This is a blog also has more technical resources, such as the patch-clamp tutorials, that I hope may be helpful to undergraduate and new graduate students in neuroscience.

# %% [markdown]
# ## Open access books
#
# Here, I revisit several very interesting references highlighted by David on his website "[spikes and bursts](https://spikesandbursts.wordpress.com/resources/)".
#
#
# - Statistics and data science with Python:
#     - G. James, D. Witten, T. Hastie, R. Tibshirani, & J. Taylor, **An Introduction to Statistical Learning**, [[website](https://www.statlearning.com), [download Python edition](https://hastie.su.domains/ISLP/ISLP_website.pdf.download.html)]
#     - A.B. Downey, **Elements of data science**, With Python Jupyter Notebooks [[website](https://allendowney.github.io/ElementsOfDataScience/index.html)]
#     - D. Navarro & E. Weed, **Learning Statistics with Python**, 2021 [[website](https://ethanweed.github.io/pythonbook/landingpage.html#)]
#     - J. VanderPlas, **Python Data Science Handbook** [[website](https://jakevdp.github.io/PythonDataScienceHandbook/)]

# %% [markdown]
# ## References
#
# 1. P. Blainey, M. Krzywinski, & N. Altman, **Replication**. *Nat Methods* 11, 879–880 (2014). [https://doi.org/10.1038/nmeth.3091](https://doi.org/10.1038/nmeth.3091)

# %% [markdown]
# Guides and recommendations
